# %%
import pandas as pd

# %%
df = pd.read_csv ('TEST Backup.csv', encoding='latin1')

DFrows = df.shape[0]
DFcolumns = df.shape[1]

print(f"rows = {DFrows} and columns = {DFcolumns}")
# Out:
# rows = 1420 and columns = 172

# %%
employeeInformation = df.loc[1:DFrows,'employee_name':'languages']
employeeInformation.tail(5)
# Out:
#                          employee_name  years_of_experience  \
# 1                     Pablo Ageas, Jr.                 18.0
# 2  Waleed Mohamed Saber Mohamed Sarhan                 23.0
# 3            Aly AbdelMonem Abdelhalim                 16.0
# 4                 Vijayakumar Sadaiyan                 19.0
# 5                 Mohammed Saleh Gomaa                 28.0
#
#   regional_years_of_experience years_with_dorsch                  position  \
# 1                          NaN               NaN           Safety Engineer
# 2                          NaN               NaN          Senior Architect
# 3                          NaN               NaN  Senior Planning Engineer
# 4                          NaN               NaN   Senior Safety Inspector
# 5                          NaN               NaN         Planning Engineer
#
#     dob nationality marital_status driving_license  \
# 1  1979    Filipino        Married             NaN
# ...

# %%
employeeEducation = df.loc[1:DFrows,'education_date_1':'professional_training']
employeeEducation.head(5)
# Out:
#   education_date_1                    education_name_of_institution_1  \
# 1             2008                                   Bachelor of Laws
# 2             1997  Bachelor of Science -Architectural Engineering...
# 3             2003                            B.Sc. Civil Engineering
# 4             2016  Bachelor of Science in Fire & Industrial Safet...
# 5             2000  Diploma in Project Management, American Univer...
#
#   education_country_1 education_date_2  \
# 1                 NaN             2002
# 2               Egypt              NaN
# 3               Egypt              NaN
# 4              India              2000
# 5               Egypt             1998
#
#                      education_name_of_institution_2 education_country_2  \
# 1         Bachelor of Science in Business Management                 NaN
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# ...

# %%
employeeExperience = df.loc[1:DFrows,'name_current_employer':'duties_20']
employeeExperience.head(5)
# Out:
#                  name_current_employer address_current_employer telephone  \
# 1                   Arcadis consulting                      NaN       NaN
# 2  DORSCH GRUPPE Middle East â Qatar             Qatar / Doha       NaN
# 3                AECOM Middle East Ltd                    Qatar       NaN
# 4                 Dorsch Gruppe, Qatar                    Qatar       NaN
# 5     Dorsch Holding GmbH, Doha, Qatar                      NaN       NaN
#
#    fax email            job_title year_current contact_reference  from_1  \
# 1  NaN   NaN                  NaN          NaN               NaN    2019
# 2  NaN   NaN      Project Manager          NaN               NaN  16-Jun
# 3  NaN   NaN                  NaN          NaN               NaN  16-Oct
# 4  NaN   NaN  Sr.Safety Inspector            1               NaN    2021
# 5  NaN   NaN                  NaN          NaN               NaN  16-Apr
#
#         to_1  ... project_19 country_19 duties_19 from_20 to_20 pos_20  \
# ...

# %%
TransactionTimestamps = df.loc[1:DFrows,['employee_name','Date Created','Date Updated']]
TransactionTimestamps.head(5)
# Out:
#                          employee_name Date Created               Date Updated
# 1                     Pablo Ageas, Jr.          NaN                        NaN
# 2  Waleed Mohamed Saber Mohamed Sarhan          NaN                        NaN
# 3            Aly AbdelMonem Abdelhalim          NaN                        NaN
# 4                 Vijayakumar Sadaiyan          NaN  18-03-2022 at 04:14:20 PM
# 5                 Mohammed Saleh Gomaa          NaN  04-01-2023 at 03:22:07 PM
